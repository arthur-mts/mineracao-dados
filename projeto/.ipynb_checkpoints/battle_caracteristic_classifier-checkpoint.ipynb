# %%
from ipynb.fs.full.extracao import fetch_pokedex, damage_matrix, Types
import numpy as np
import pandas as pd
from enum import Enum
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
import seaborn as sn
import matplotlib.pyplot as plt
import PIL
from imageio.v2 import imread
import urllib
from sklearn import svm
import matplotlib.gridspec as gridspec
from sklearn import tree

# %%
class BattleRole(Enum):
    Attacker = "Attacker"
    SPAttacker = "SPAttacker"
    Tank = "Tank"

# %%
status_columns = ["base_hp", "base_attack", "base_defense", "base_special_attack", "base_special_defense", "base_speed"]
pokedex_df = fetch_pokedex()

# %%
pokedex_df.head()
# Out:
#    color  is_legendary  is_mythical        name      shape  \
# 0  green         False        False   bulbasaur  quadruped
# 1  green         False        False     ivysaur  quadruped
# 2  green         False        False    venusaur  quadruped
# 3    red         False        False  charmander    upright
# 4    red         False        False  charmeleon    upright
#
#                                            image_url  base_hp  base_attack  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...       45           49
# 1  https://raw.githubusercontent.com/PokeAPI/spri...       60           62
# 2  https://raw.githubusercontent.com/PokeAPI/spri...       80           82
# 3  https://raw.githubusercontent.com/PokeAPI/spri...       39           52
# 4  https://raw.githubusercontent.com/PokeAPI/spri...       58           64
#
#    base_defense  base_special_attack  base_special_defense  base_speed
# 0            49                   65                    65          45
# 1            63                   80                    80          60
# 2            83                  100                   100          80
# 3            43                   60                    50          65
# 4            58                   80                    65          80

# %%
pokemon_by_role = {
    "SPAttacker": ["gardevoir",smile "slowbro", "tangrowth", "manaphy", "sceptile", "gengar", "alakazam", "mew"],
    ##, "keldeo"
    "Attacker": ["crawdaunt", "talonflame", "garchomp", "weavile", "infernape", "lucario", "salamence", "gyarados",
                 "dragonite"],
    "Tank": ["clefable", "tyranitar", "gastrodon", "chansey", "gliscor", "shuckle", "steelix", "cloyster", "bastiodon"]
}

# %%
train_data = pd.DataFrame(
    columns=status_columns + ["role"]
)

# %%
for key in pokemon_by_role.keys():
    pokemons = pokemon_by_role[key]

    for pokemon in pokemons:
        pokemon_data = pokedex_df[pokedex_df["name"] == pokemon]
        row = {
            "role": key
        }
        print(pokemon)
        for status in status_columns:
            row[status] = pokemon_data[status].values[0]
        row_series = pd.Series(row)
        train_data = pd.concat(
            [train_data, row_series.to_frame().T],
            ignore_index=True
        )
# Out:
# gardevoir
# slowbro
# tangrowth
# manaphy
# sceptile
# gengar
# alakazam
# mew
# crawdaunt
# talonflame
# garchomp
# weavile
# infernape
# lucario
# salamence
# gyarados
# dragonite
# clefable
# tyranitar
# gastrodon
# chansey
# gliscor
# shuckle
# steelix
# cloyster
# bastiodon

# %%
#SVM e Arvore de decisão
X_train, X_test, y_train, y_test = train_test_split(train_data[status_columns], train_data["role"], random_state=2)
pipeline = make_pipeline(StandardScaler(), LogisticRegression())
# pipeline = make_pipeline(svm.SVC())
# pipeline = make_pipeline(tree.DecisionTreeClassifier())
pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %%
y_pred = pipeline.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 7))
sn.heatmap(conf_matrix, annot=True)
# Out:
# <AxesSubplot: >

# %%
pokedex_df_sample = pokedex_df.sample(n=20)

pokedex_df_sample = pokedex_df_sample.assign(
    role=pipeline.predict(pokedex_df_sample[status_columns])
).reset_index()

f, axarr = plt.subplots(2, 10, figsize=(10, 10), gridspec_kw = {'wspace':0, 'hspace':3})

for i in range(2):
    for j in range(10):
        image_url = pokedex_df_sample.loc[(i * 10) + j]["image_url"]
        image_file = imread(image_url)
        name = pokedex_df_sample.loc[(i * 10) + j]["name"]
        role = pokedex_df_sample.loc[(i * 10) + j]["role"]
        axarr[i][j].text(10, 5, role, bbox={'facecolor': 'white', 'pad': 1})

        axarr[i][j].imshow(image_file)
        axarr[i][j].axis('off')
        axarr[i][j].set_aspect('equal')
        

plt.show()
# Out:
# /home/arthur/.local/lib/python3.10/site-packages/PIL/Image.py:992: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
pokedex_df_sample
# Out:
#     index   color  is_legendary  is_mythical       name      shape  \
# 0      97     red         False        False     krabby      armor
# 1     725   green         False        False   dhelmise       blob
# 2     215   brown         False        False     swinub  quadruped
# 3     671   brown         False         True  volcanion  quadruped
# 4      12   brown         False        False     weedle      armor
# 5     526     red         False        False    crustle      armor
# 6     639   white         False        False    swirlix       legs
# 7     612     red         False        False    delphox    upright
# 8     212   brown         False        False   ursaring    upright
# 9     548    blue         False        False   ducklett      wings
# 10    280    gray         False        False    nincada      armor
# 11    453   brown         False        False  mamoswine  quadruped
# 12    641    blue         False        False      inkay  tentacles
# 13    510  yellow         False        False   sewaddle      armor
# 14     25  yellow         False        False     raichu    upright
# 15     66    gray         False        False    machoke   humanoid
# 16    301  yellow         False        False     plusle    upright
# 17     15   brown         False        False     pidgey      wings
# 18    358    pink         False        False   gorebyss   squiggle
# 19      9   green         False        False   caterpie      armor
#
#                                             image_url  base_hp  base_attack  \
# 0   https://raw.githubusercontent.com/PokeAPI/spri...       30          105
# 1   https://raw.githubusercontent.com/PokeAPI/spri...       70          131
# 2   https://raw.githubusercontent.com/PokeAPI/spri...       50           50
# 3   https://raw.githubusercontent.com/PokeAPI/spri...       80          110
# 4   https://raw.githubusercontent.com/PokeAPI/spri...       40           35
# 5   https://raw.githubusercontent.com/PokeAPI/spri...       70          105
# 6   https://raw.githubusercontent.com/PokeAPI/spri...       62           48
# 7   https://raw.githubusercontent.com/PokeAPI/spri...       75           69
# 8   https://raw.githubusercontent.com/PokeAPI/spri...       90          130
# 9   https://raw.githubusercontent.com/PokeAPI/spri...       62           44
# 10  https://raw.githubusercontent.com/PokeAPI/spri...       31           45
# 11  https://raw.githubusercontent.com/PokeAPI/spri...      110          130
# 12  https://raw.githubusercontent.com/PokeAPI/spri...       53           54
# 13  https://raw.githubusercontent.com/PokeAPI/spri...       45           53
# 14  https://raw.githubusercontent.com/PokeAPI/spri...       60           90
# 15  https://raw.githubusercontent.com/PokeAPI/spri...       80          100
# 16  https://raw.githubusercontent.com/PokeAPI/spri...       60           50
# 17  https://raw.githubusercontent.com/PokeAPI/spri...       40           45
# 18  https://raw.githubusercontent.com/PokeAPI/spri...       55           84
# 19  https://raw.githubusercontent.com/PokeAPI/spri...       45           30
#
#     base_defense  base_special_attack  base_special_defense  base_speed  \
# 0             90                   25                    25          50
# 1            100                   86                    90          40
# 2             40                   30                    30          50
# 3            120                  130                    90          70
# 4             30                   20                    20          50
# 5            125                   65                    75          45
# 6             66                   59                    57          49
# 7             72                  114                   100         104
# 8             75                   75                    75          55
# 9             50                   44                    50          55
# 10            90                   30                    30          40
# 11            80                   70                    60          80
# 12            53                   37                    46          45
# 13            70                   40                    60          42
# 14            55                   90                    80         110
# 15            70                   50                    60          45
# 16            40                   85                    75          95
# 17            40                   35                    35          56
# 18           105                  114                    75          52
# 19            35                   20                    20          45
#
#           role
# 0     Attacker
# 1     Attacker
# 2         Tank
# 3   SPAttacker
# 4         Tank
# 5         Tank
# 6         Tank
# 7   SPAttacker
# 8     Attacker
# 9         Tank
# 10        Tank
# 11    Attacker
# 12        Tank
# 13        Tank
# 14    Attacker
# 15        Tank
# 16  SPAttacker
# 17        Tank
# 18  SPAttacker
# 19        Tank

# %%
from ipynb.fs.full.extracao import fetch_pokedex, damage_matrix, Types
import pandas as pd
from enum import Enum
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
import seaborn as sn
import matplotlib.pyplot as plt
from imageio.v2 import imread
from sklearn import svm
import numpy as np
from sklearn.model_selection import GridSearchCV

# %%
class BattleRole(Enum):
    Attacker = "Attacker"
    SPAttacker = "SPAttacker"
    Tank = "Tank"
    SPTank = "SPTank" 
    Sweeper = "Sweeper"  ## Rapida velocidade e ataque

# %%
status_columns = ["base_hp", "base_attack", "base_defense", "base_special_attack", "base_special_defense", "base_speed"]
pokedex_df = fetch_pokedex()

# %%
pokedex_df["status_mean"] = pokedex_df[status_columns].mean(axis = 1)
pokedex_df = pd.concat([pokedex_df, pd.DataFrame(pokedex_df["type"].to_list(), columns = ['type1', 'type2'])], axis=1)

# %% [markdown]
# Média dos status

# %%
pokedex_df["status_mean"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Calculando percentis

# %%
pokedex_df["status_mean"].quantile([.01,0.05, 0.25, .4, 0.5, .9]).plot.bar()
# Out:
# <Axes: >

# %%
valor_mediana = pokedex_df["status_mean"].quantile(0.6)

# %% [markdown]
# Aqui vou tirar somente 50% dos pokemons com a maior media dos status, para evitar que pokemons fracos sejam colocados nas predições.
# Também vou checar a distribuição de tipo e shape depois.

# %%
pokedex_df_filtered = pokedex_df[pokedex_df["status_mean"] >= valor_mediana]

# %% [markdown]
# Checando a distribuição de tipos

# %%
pokedex_df_filtered['type1'].value_counts().plot(kind = 'bar')
plt.xlabel('Tipo')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %% [markdown]
# Comparando com a distribuição original, podemos ver que não mudou muito.

# %%
pokedex_df['type1'].value_counts().plot(kind = 'bar')
plt.xlabel('Tipo')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
pokemon_by_role = {
    "SPAttacker": ["camerupt", "charizard", "rayquaza","ampharos", "gardevoir", "slowbro", "tangrowth", "manaphy", "sceptile", "gengar","gengar", "alakazam", "mew", "espeon", "mewtwo"],
    ##, "keldeo"
    "Attacker": ["gallade", "rampardos", "blaziken","heracross","groudon", "crawdaunt","garchomp", "weavile", "infernape", "lucario", "salamence", "gyarados", "monferno",
                 "dragonite", "excadrill"],
    "Tank": ["slaking", "tangrowth", "clefable", "tyranitar", "gastrodon", "chansey", "gliscor", "shuckle", "steelix", "cloyster", "bastiodon", "snorlax", "quagsire", "wobbuffet", "wailord","hariyama", "wigglytuff"]
}

# %%
key_cnt = {}
for key in pokemon_by_role:
    key_cnt[key] = len(pokemon_by_role[key])
plt.bar(key_cnt.keys(), key_cnt.values())
# Out:
# <BarContainer object of 3 artists>

# %%
train_data = pd.DataFrame(
    columns=status_columns + ["role"]
)

# %%
for key in pokemon_by_role.keys():
    pokemons = pokemon_by_role[key]

    for pokemon in pokemons:
        pokemon_data = pokedex_df_filtered[pokedex_df_filtered["name"] == pokemon]
        row = {
            "role": key
        }
        for status in status_columns:
            print(pokemon)
            row[status] = pokemon_data[status].values[0]
        row_series = pd.Series(row)
        train_data = pd.concat(
            [train_data, row_series.to_frame().T],
            ignore_index=True
        )
# Out:
# camerupt
# camerupt
# camerupt
# camerupt
# camerupt
# camerupt
# charizard
# charizard
# charizard
# charizard
# charizard
# charizard
# rayquaza
# rayquaza
# rayquaza
# rayquaza
# rayquaza
# rayquaza
# ampharos
# ampharos
# ampharos
# ampharos
# ampharos
# ampharos
# gardevoir
# gardevoir
# gardevoir
# gardevoir
# gardevoir
# gardevoir
# slowbro
# slowbro
# slowbro
# slowbro
# slowbro
# slowbro
# tangrowth
# tangrowth
# tangrowth
# tangrowth
# tangrowth
# tangrowth
# manaphy
# manaphy
# manaphy
# manaphy
# manaphy
# manaphy
# sceptile
# sceptile
# sceptile
# sceptile
# sceptile
# sceptile
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# gengar
# alakazam
# alakazam
# alakazam
# alakazam
# alakazam
# alakazam
# mew
# mew
# mew
# mew
# mew
# mew
# espeon
# espeon
# espeon
# espeon
# espeon
# espeon
# mewtwo
# mewtwo
# mewtwo
# mewtwo
# mewtwo
# mewtwo
# gallade
# gallade
# gallade
# gallade
# gallade
# gallade
# rampardos
# rampardos
# rampardos
# rampardos
# rampardos
# rampardos
# blaziken
# blaziken
# blaziken
# blaziken
# blaziken
# blaziken
# heracross
# heracross
# heracross
# heracross
# heracross
# heracross
# groudon
# groudon
# groudon
# groudon
# groudon
# groudon
# banette
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [14], line 11
#       9 for status in status_columns:
#      10     print(pokemon)
# ---> 11     row[status] = pokemon_data[status].values[0]
#      12 row_series = pd.Series(row)
#      13 train_data = pd.concat(
#      14     [train_data, row_series.to_frame().T],
#      15     ignore_index=True
#      16 )
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
#SVM e Arvore de decisão
X_train, X_test, y_train, y_test = train_test_split(train_data[status_columns], train_data["role"], random_state=2)
# pipeline = make_pipeline(StandardScaler(), LogisticRegression())
pipeline = make_pipeline(svm.SVC())
# pipeline = make_pipeline(tree.DecisionTreeClassifier())
pipeline.fit(X_train, y_train)
pipeline.score(X_test, y_test)

# %%
models = [
    ("SVM", svm.SVC()),
    ("LogisticRegression", LogisticRegression(solver = 'newton-cholesky')),
    ("RandomForestClassifier", RandomForestClassifier(max_depth=4)),
    ("DecisionTreeClassifier", DecisionTreeClassifier(max_depth=4)),
]
scores = []
for (name, model) in models:
    model.fit(X_train, y_train)
    score = model.score(X_test, y_test)
    print(f"{name} = {score}")
    scores.append(score)

bestModelIdx = scores.index(max(scores))
print(f"Melhor modelo: {models[bestModelIdx][0]}")

# %%
model = models[bestModelIdx][1]

# %%
models

# %%
param_grid = {
              'solver': ['newton-cg', 'newton-cg', 'newton-cg'],
                'tol': [.1, .01, .001, .0002]
              }

pipeline = GridSearchCV(estimator=models[1][1], param_grid=param_grid, cv=5, scoring='accuracy', refit=True, n_jobs=10)
pipeline.fit(X_train, y_train)
print(pipeline.score(X_test, y_test))

# %%
y_pred = model.predict(X_test)
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(5, 7))
sn.heatmap(conf_matrix, annot=True)

# %%
pokedex_df_sample = pokedex_df.sample(n=20)

pokedex_df_sample = pokedex_df_sample.assign(
    role=pipeline.predict(pokedex_df_sample[status_columns])
).reset_index()

f, axarr = plt.subplots(2, 10, figsize=(10, 10), gridspec_kw={'wspace': 0, 'hspace': 3})

for i in range(2):
    for j in range(10):
        image_url = pokedex_df_sample.loc[(i * 10) + j]["image_url"]
        image_file = imread(image_url)
        name = pokedex_df_sample.loc[(i * 10) + j]["name"]
        role = pokedex_df_sample.loc[(i * 10) + j]["role"]
        axarr[i][j].text(10, 5, role, bbox={'facecolor': 'white', 'pad': 1})

        axarr[i][j].imshow(image_file)
        axarr[i][j].axis('off')
        axarr[i][j].set_aspect('equal')

plt.show()
